# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
df=pd.read_excel('customer_retention_dataset.xlsx')
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.tail()
# Out:
#     1Gender of respondent 2 How old are you?   \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
df.isnull()
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                    False                False
# 1                    False                False
# 2                    False                False
# 3                    False                False
# 4                    False                False
# ..                     ...                  ...
# 264                  False                False
# 265                  False                False
# 266                  False                False
# 267                  False                False
# 268                  False                False
#
#      3 Which city do you shop online from?  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 264                                  False
# ...

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        1                    1
# 1                        0                    0
# 2                        0                    0
# 3                        1                    0
# 4                        0                    0
# ..                     ...                  ...
# 264                      0                    0
# 265                      0                    1
# 266                      0                    2
# 267                      0                    4
# 268                      0                    2
#
#      3 Which city do you shop online from?  \
# 0                                        2
# 1                                        2
# 2                                        4
# 3                                        6
# 4                                        0
# ..                                     ...
# 264                                     10
# ...

# %%
df.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.327138             1.330855
# std                 0.470042             1.183774
# min                 0.000000             0.000000
# 25%                 0.000000             0.000000
# 50%                 0.000000             1.000000
# 75%                 1.000000             2.000000
# max                 1.000000             4.000000
#
#        3 Which city do you shop online from?  \
# count                             269.000000
# mean                                4.494424
# std                                 3.187687
# min                                 0.000000
# 25%                                 2.000000
# 50%                                 4.000000
# 75%                                 7.000000
# max                                10.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# ...

# %%
dfcor=df.corr()
dfcor
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                               0.046169
# 3 Which city do you shop online from?                            0.080912
# 4 What is the Pin Code of where you shop online...              -0.260365
# 5 Since How Long You are Shopping Online ?                      -0.057096
# ...                                                                   ...
# Longer delivery period                                           0.060838
# Change in website/Application design                            -0.164818
# Frequent disruption when moving from one page t...              -0.256638
# Website is as efficient as before                                0.055663
# Which of the Indian online retailer would you r...              -0.003372
#
#                                                     2 How old are you?   \
# ...

# %%
dfcor['47 Getting value for money spent']
# Out:
# 1Gender of respondent                                                   0.123718
# 2 How old are you?                                                      0.046574
# 3 Which city do you shop online from?                                   0.198166
# 4 What is the Pin Code of where you shop online from?                   0.109155
# 5 Since How Long You are Shopping Online ?                             -0.262638
#                                                                           ...
# Longer delivery period                                                 -0.304705
# Change in website/Application design                                   -0.420287
# Frequent disruption when moving from one page to another               -0.114168
# Website is as efficient as before                                       0.134624
# Which of the Indian online retailer would you recommend to a friend?   -0.230271
# Name: 47 Getting value for money spent, Length: 71, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(dfcor,cmap='Blues',annot=False,linewidths=.5,linecolor='black')
# Out:
# <AxesSubplot:>

# %%
dfcor.plot(kind='bar',subplots=True,layout=(8,9),figsize=(55,53))
# Out:
# array([[<AxesSubplot:title={'center':'1Gender of respondent'}>,
#         <AxesSubplot:title={'center':'2 How old are you? '}>,
#         <AxesSubplot:title={'center':'3 Which city do you shop online from?'}>,
#         <AxesSubplot:title={'center':'4 What is the Pin Code of where you shop online from?'}>,
#         <AxesSubplot:title={'center':'5 Since How Long You are Shopping Online ?'}>,
#         <AxesSubplot:title={'center':'6 How many times you have made an online purchase in the past 1 year?'}>,
#         <AxesSubplot:title={'center':'7 How do you access the internet while shopping on-line?'}>,
#         <AxesSubplot:title={'center':'8 Which device do you use to access the online shopping?'}>,
#         <AxesSubplot:title={'center':'9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '}>],
# ...

# %%
df.plot(kind='box',subplots=True,layout=(8,9),figsize=(55,53))
# Out:
# 1Gender of respondent                                                     AxesSubplot(0.125,0.799681;0.0731132x0.0803191)
# 2 How old are you?                                                      AxesSubplot(0.212736,0.799681;0.0731132x0.0803...
# 3 Which city do you shop online from?                                   AxesSubplot(0.300472,0.799681;0.0731132x0.0803...
# 4 What is the Pin Code of where you shop online from?                   AxesSubplot(0.388208,0.799681;0.0731132x0.0803...
# 5 Since How Long You are Shopping Online ?                              AxesSubplot(0.475943,0.799681;0.0731132x0.0803...
#                                                                                               ...
# Longer delivery period                                                    AxesSubplot(0.388208,0.125;0.0731132x0.0803191)
# Change in website/Application design                                      AxesSubplot(0.475943,0.125;0.0731132x0.0803191)
# ...

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                 1.434161             0.280013
# 1                 0.697272             1.126343
# 2                 0.697272             1.126343
# 3                 1.434161             1.126343
# 4                 0.697272             1.126343
# ..                     ...                  ...
# 264               0.697272             1.126343
# 265               0.697272             0.280013
# 266               0.697272             0.566318
# 267               0.697272             2.258979
# 268               0.697272             0.566318
#
#      3 Which city do you shop online from?  \
# 0                                 0.783977
# 1                                 0.783977
# 2                                 0.155393
# 3                                 0.473190
# 4                                 1.412561
# ..                                     ...
# 264                               1.730357
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  4,  16,  20,  30,  35,  49,  79,  88,  95, 112, 116, 133, 142,
#        159, 162, 196, 207, 234, 237, 262], dtype=int64), array([11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11,
#        11, 11, 11], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        1                    1
# 1                        0                    0
# 2                        0                    0
# 3                        1                    0
# 5                        0                    1
# ..                     ...                  ...
# 264                      0                    0
# 265                      0                    1
# 266                      0                    2
# 267                      0                    4
# 268                      0                    2
#
#      3 Which city do you shop online from?  \
# 0                                        2
# 1                                        2
# 2                                        4
# 3                                        6
# 5                                        9
# ..                                     ...
# 264                                     10
# ...

# %%
df_new.shape
# Out:
# (249, 71)

# %%
df.shape
# Out:
# (269, 71)

# %%
data_loss=((269-249)/269)*100
data_loss
# Out:
# 7.434944237918216

# %% [markdown]
# the data_loss percentage is 7. so we are not going to perform the process of outliers removal

# %% [markdown]
# the data is categorical so we are not going to perform the removal of skewness process too

# %%
df.plot(kind='hist',subplots=True,layout=(8,9),figsize=(55,53))
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
# ...

# %%
df.plot(kind='kde',subplots=True,layout=(8,9),figsize=(55,53))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
# ...

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# 0    181
# 1     88
# Name: 1Gender of respondent, dtype: int64
# 1    81
# 0    79
# 2    70
# 4    20
# 3    19
# Name: 2 How old are you? , dtype: int64
# 2     58
# 4     43
# 9     40
# 0     37
# 6     27
# 10    18
# 3     18
# 5     12
# 7      9
# 8      5
# 1      2
# Name: 3 Which city do you shop online from?, dtype: int64
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 250001     9
# 173229     9
# 173212     9
# 560010     8
# 132036     8
# 122018     8
# 560037     8
# 110008     7
# 110011     7
# 201306     7
# 110014     6
# 110018     6
# 201305     5
# 201008     5
# 201009     5
# 201312     5
# 244001     5
# 530068     5
# 122009     4
# 201001     4
# 560003     4
# 201304     4
# 110009     4
# 201303     4
# 560002     4
# 560018     4
# 110042     4
# 110030     4
# 201005     4
# 110039     4
# 560013     3
# 203001     2
# 203202     1
# 560001     1
# 203207     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64
# ...

# %% [markdown]
# now making the imbalance dataset ,balanced

# %%
x=df.drop('47 Getting value for money spent',axis =1)
x
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        1                    1
# 1                        0                    0
# 2                        0                    0
# 3                        1                    0
# 4                        0                    0
# ..                     ...                  ...
# 264                      0                    0
# 265                      0                    1
# 266                      0                    2
# 267                      0                    4
# 268                      0                    2
#
#      3 Which city do you shop online from?  \
# 0                                        2
# 1                                        2
# 2                                        4
# 3                                        6
# 4                                        0
# ..                                     ...
# 264                                     10
# ...

# %%
y=df.iloc[:,46]
y
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 264    2
# 265    1
# 266    0
# 267    2
# 268    1
# Name: 47 Getting value for money spent, Length: 269, dtype: int32

# %%
x.shape
# Out:
# (269, 70)

# %%
y.shape
# Out:
# (269,)

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()
x1,y1=smt.fit_resample(x,y)

# %%
x1.shape
# Out:
# (447, 70)

# %%
y1.shape
# Out:
# (447,)

# %% [markdown]
# now scaling the dataset for making the machine to learn it easily:-

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
x=ss.fit_transform(x1)
x
# Out:
# array([[ 1.41421356, -0.30966116, -0.91843985, ..., -1.43332712,
#         -1.10398539,  1.77616877],
#        [-0.70710678, -1.0916868 , -0.91843985, ...,  0.2416983 ,
#         -0.63623044,  0.45658854],
#        [-0.70710678, -1.0916868 , -0.34505631, ...,  1.07921101,
#         -1.10398539,  1.33630869],
#        ...,
#        [ 1.41421356,  0.47236448,  1.08840253, ...,  0.2416983 ,
#          0.7670344 , -0.8629917 ],
#        [-0.70710678, -1.0916868 ,  1.37509429, ..., -1.43332712,
#         -1.10398539, -0.8629917 ],
#        [ 1.41421356, -0.30966116,  1.08840253, ..., -0.17705806,
#          0.29927945, -0.8629917 ]])

# %%
x1=pd.DataFrame(x)
x1
# Out:
#            0         1         2         3         4         5         6   \
# 0    1.414214 -0.309661 -0.918440 -0.831721  0.798655 -0.740173 -2.701264
# 1   -0.707107 -1.091687 -0.918440 -0.831567  0.798655 -0.147239  1.319152
# 2   -0.707107 -1.091687 -0.345056 -0.160520 -0.023923 -0.147239 -1.361125
# 3    1.414214 -1.091687  0.228327 -0.670043 -0.023923  1.038630 -1.361125
# 4   -0.707107 -1.091687 -1.491823  2.256418 -0.846501 -1.926041  1.319152
# ..        ...       ...       ...       ...       ...       ...       ...
# 442  1.414214 -1.091687 -1.491823  2.476564  1.621234  1.038630 -0.020987
# 443  1.414214 -0.309661  1.088403 -0.160542 -0.023923 -0.147239 -0.020987
# 444  1.414214  0.472364  1.088403 -0.160542 -0.846501 -0.147239 -0.020987
# 445 -0.707107 -1.091687  1.375094 -0.367073 -1.669080  1.038630 -1.361125
# 446  1.414214 -0.309661  1.088403 -0.160557 -0.023923 -0.147239 -0.020987
#
#            7         8         9         10        11        12        13  \
# ...

# %%
x1.shape
# Out:
# (447, 70)

# %%
y1.shape
# Out:
# (447,)

# %% [markdown]
# now the dataset is ready for the machine to learn with the help of different models
